# %%
import pandas as pd
import os
import pickle

# %%
yrs = [i for i in range(1999, 2021)]

# %%
result_df = list()
for yr in yrs:
    print(yr)
    with open(f'./title_dict_pkl/{yr}-title.pkl', 'rb') as f:
        data = pickle.load(f, encoding='utf-8')
        
    for i in data.items():
        df = pd.DataFrame()

        contents = i[1]
        month = [i[0] for _ in range(len(contents) // 2)]

        try:
            titles = [contents[i] for i in range(len(contents)) if i % 2 == 0]
            writers = [contents[i] for i in range(len(contents)) if i % 2 == 1]
        except:
            pass

        df['year'] = [yr for _ in range(len(contents) // 2)]
        df['month'] = month
        df['title'] = titles
        df['writer'] = writers
        df['ordered'] = [yr for _ in range(len(contents) // 2)]


        result_df.append(df)
# Out:
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020

# %%
df = pd.concat(result_df)
df.shape
# Out:
# (12250, 4)

# %%
result_df[5]
# Out:
#     year month                      title  \
# 0   1999     8                     이완용 평전
# 1   1999     8                     직접 팔아라
# 2   1999     8               송영과 떠나는 음악여행
# 3   1999     8                  담배끊는 그림최면
# 4   1999     8                존재는 눈물을 흘린다
# 5   1999     8            길 끝나는 곳에 암자가 있다
# 6   1999     8          물리학자는 영화에서 과학을 본다
# 7   1999     8          책의 역사 : 문자에서 텍스트로
# 8   1999     8                     여행 그림책
# 9   1999     8  엄마의 재치있는 질문이 아이의 창의력을 키운다
# 10  1999     8          365일 놀이로 창의력을 키운다
# 11  1999     8                     어른의 학교
# 12  1999     8       지금 알고 있는 걸 그때도 알았더라면
# 13  1999     8                     영어공부혁명
# 14  1999     8              문학과 예술의 사회사 1
# 15  1999     8                   뒤집어본 영문법
# 16  1999     8                   내 짝꿍 최영대
# 17  1999     8              꼬리에 꼬리를 무는 한자
# 18  1999     8                기차는 7시에 떠나네
# 19  1999     8                       강아지똥
# 20  1999     8                     희망의 누드
# 21  1999     8                  아마존의 성공비밀
# 22  1999     8            한국 인문학의 서양 콤플렉스
# 23  1999     8                       헤르메스
# 24  1999     8                     감시와 처벌
# 25  1999     8             마테오 리치, 기억의 궁전
# 26  1999     8              인간은 왜 병에 걸리는가
# 27  1999     8         홈페이지 디자인을 위한 플래시 4
# 28  1999     8                   화산이 왈칵왈칵
# 29  1999     8                   바다가 바글바글
# 30  1999     8               너에게 변두리를 보낸다
# 31  1999     8                미술과 역사 사이에서
# 32  1999     8            김희선 BEAUTY BOOK
# 33  1999     8               스.타.카.토 내 영혼
# 34  1999     8       위대한 지식인들에 관한 끔찍한 보고서
# 35  1999     8         산해관에서 중국역사와 사상을 보다
# 36  1999     8                  티벳에서 온 편지
# 37  1999     8        유희열 삽화집 - 익숙한 그 집 앞
# 38  1999     8                 인간의 내밀한 역사
# 39  1999     8                   죽은 자의 몸값
# 40  1999     8                    마지막 칸타타
# 41  1999     8                   유럽음악기행 1
# 42  1999     8                     전략적 사고
# 43  1999     8           님이여, 그 숲을 떠나지 마오
# 44  1999     8                  앵무새의 정리 1
# 45  1999     8                    안으로의 여행
# 46  1999     8                         농담
# 47  1999     8                  21세기 지식경영
# 48  1999     8                한국어판 UML 입문
# 49  1999     8                 최화정의 맛있는 책
#
#                                                writer
# 0                                  [(윤덕한 , (지은이), |)]
# 1                     [(마이클 델 (지은이), 김중찬 , (옮긴이), |)]
# 2                                   [(송영 , (지은이), |)]
# 3                                  [(김영국 , (지은이), |)]
# 4                                  [(공지영 , (지은이), |)]
# 5                                  [(정찬주 , (지은이), |)]
# 6                                  [(정재승 , (지은이), |)]
# 7                   [(브뤼노 블라셀 (지은이), 권명희 , (옮긴이), |)]
# 8                               [(안노 미쓰마사 , (그림), |)]
# 9                    [(호원희 (지은이) | 한울림어린이, (한울림), |)]
# 10                  [(트리시 쿠프너 (지은이), 이원영 , (옮긴이), |)]
# 11            [(이윤기 (지은이), 정병규 (엮은이), 정재규 , (그림), |)]
# 12                                 [(류시화 , (엮은이), |)]
# 13                                  [(정철 , (지은이), |)]
# 14       [(아르놀트 하우저 (지은이), 반성완, 백낙청, 염무웅 , (옮긴이), |)]
# 15                               [(네오퀘스트 , (지은이), |)]
# 16                         [(채인선 (글), 정순희 , (그림), |)]
# 17                                 [(한호림 , (지은이), |)]
# 18                                 [(신경숙 , (지은이), |)]
# 19                         [(권정생 (글), 정승각 , (그림), |)]
# 20                                 [(신현림 , (지은이), |)]
# 21            [(레베카 손더스 (지은이), 세스컴 전략기획팀 , (옮긴이), |)]
# 22                                 [(이진우 , (지은이), |)]
# 23                    [(미셸 세르 (지은이), 이규현 , (옮긴이), |)]
# 24                    [(미셸 푸코 (지은이), 오생근 , (옮긴이), |)]
# 25                  [(조너선 스펜스 (지은이), 주원준 , (옮긴이), |)]
# 26          [(랜덜프 네스, 조지 윌리엄스 (지은이), 최재천 , (옮긴이), |)]
# 27                     [(최인수 (지은이) | 대청, (대청미디어), |)]
# 28                  [(아니타 가너리 (지은이), 김은지 , (옮긴이), |)]
# 29                  [(아니타 가너리 (지은이), 이명연 , (옮긴이), |)]
# 30                                 [(정유희 , (지은이), |)]
# 31                                 [(강우방 , (지은이), |)]
# 32                           [(중앙M&B 편집부 , (지은이), |)]
# 33                                 [(김정란 , (지은이), |)]
# 34                      [(폴 존슨 (지은이), 김욱 , (옮긴이), |)]
# 35                                 [(금장태 , (지은이), |)]
# 36                                 [(김영종 , (지은이), |)]
# 37                                 [(유희열 , (지은이), |)]
# 38                  [(테오도르 젤딘 (지은이), 김태우 , (옮긴이), |)]
# 39                  [(엘리스 피터스 (지은이), 송은경 , (옮긴이), |)]
# 40                   [(필립 들레리스 (지은이), 임헌 , (옮긴이), |)]
# 41                                 [(황영관 , (지은이), |)]
# 42                       [(AVINASH DIXIT , (지은이), |)]
# 43                     [(박완서 (지은이) | 여백, (여백미디어), |)]
# 44                    [(드니 게즈 (지은이), 문선영 , (옮긴이), |)]
# 45                                 [(송기원 , (지은이), |)]
# 46                   [(밀란 쿤데라 (지은이), 방미경 , (옮긴이), |)]
# 47                   [(피터 드러커 (지은이), 이재규 , (옮긴이), |)]
# 48  [(마틴 파울러, Kendall Scott (지은이) | 홍릉, (홍릉과학출판사),...
# 49                                 [(최화정 , (지은이), |)]

# %%
df
# Out:
#       year month                                              title  \
# 0   1999.0     7                                       빌 게이츠@생각의 속도
# 1   1999.0     7                           쎄느강은 좌우를 나누고 한강은 남북을 가른다
# 2   1999.0     7                                       아버지들의 아버지 -상
# 3   1999.0     7                                     공자가 죽어야 나라가 산다
# 4   1999.0     7                                            마지막 칸타타
# ..     ...   ...                                                ...
# 45  2020.0     9  2020 하반기 최신판 해커스공기업 단기 합격 NCS 기본서 직업기초능력평가 + 직...
# 46  2020.0     9                          하버드 상위 1퍼센트의 비밀 (리커버 에디션)
# 47  2020.0     9                                                프리즘
# 48  2020.0     9                                          트바로티, 김호중
# 49  2020.0     9                             해리 포터와 불의 잔 (일러스트 에디션)
#
#                                             writer
# 0             [(빌 게이츠 (지은이), 안진환, 이규행 , (옮긴이), |)]
# 1                               [(홍세화 , (지은이), |)]
# 2              [(베르나르 베르베르 (지은이), 이세욱 , (옮긴이), |)]
# 3                               [(김경일 , (지은이), |)]
# 4                 [(필립 들레리스 (지은이), 임헌 , (옮긴이), |)]
# ..                                             ...
# 45  [(김소원, 김태형, 복지훈, 윤종혁, 해커스 취업교육연구소 , (지은이), |)]
# 46                              [(정주영 , (지은이), |)]
# 47                              [(손원평 , (지은이), |)]
# 48                  [(김호중 (지은이), 스토리베리 , (구성), |)]
# 49    [(J.K. 롤링 (지은이), 짐 케이 (그림), 강동혁 , (옮긴이), |)]
#
# [12250 rows x 4 columns]

# %%
pd.concat(result_df).to_csv('./Book_title_1999to2020_in_aladin.csv', index = False)
